# %%
import pandas as pd
import numpy as np

# %%
# Question 1

data_frame = d={'name':pd.Series(['Tanish','Tarun','Gaurav','Anju']),
   'age':pd.Series([12,22,45,30]),
   'mailid':pd.Series(['tgoyal.mba18fin@chitkara.edu.in','twgarg.mba18fin@chitkara.edu.in','gbansal.mba18fin@chitkara.edu.in','anju.mba18fin@chitkara.edu.in']),
   'contactno':pd.Series([9876543210,8546123420,9874125600,6234789950])}
data=pd.DataFrame(d)
print(data)
# Out:
#      name  age                            mailid   contactno
# 0  Tanish   12   tgoyal.mba18fin@chitkara.edu.in  9876543210
# 1   Tarun   22   twgarg.mba18fin@chitkara.edu.in  8546123420
# 2  Gaurav   45  gbansal.mba18fin@chitkara.edu.in  9874125600
# 3    Anju   30     anju.mba18fin@chitkara.edu.in  6234789950

# %%
# Question 2

data_set = pd.read_csv('weather.csv')
#(a)
data_set.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
# Question 2 (b)
data_set.head(10)
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1   11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2   11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3   11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4   11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5   11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6   11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7   11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8   11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9  11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# ...

# %%
# Question 2 (c)
data_set['Evaporation'].sum()
data_set['Evaporation'].mean()
data_set['Evaporation'].describe()
data_set['Evaporation'].count()
data_set['Evaporation'].max()
data_set['Evaporation'].min()
data_set['Evaporation'].median()
data_set['Evaporation'].mode()
data_set['Evaporation'].var()
# Out:
# 7.12560311400555

# %%
# Question 2 (d)
data_set.tail(5)
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 361  10/27/2008  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  10/28/2008  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  10/29/2008  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  10/30/2008  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  10/31/2008  Canberra     12.3     30.2       0.0          6.0      12.6
#
#     WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 361         NNW           76.0        SSE      ...               15
# 362           N           48.0        NNW      ...               22
# 363         ESE           43.0        ENE      ...               47
# 364          NW           46.0        SSW      ...               39
# 365          NW           78.0         NW      ...               13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
# Question 2 (e)
data_set['MinTemp'].sum()
data_set['MinTemp'].mean()
data_set['MinTemp'].describe()
data_set['MinTemp'].count()
data_set['MinTemp'].max()
data_set['MinTemp'].min()
data_set['MinTemp'].var()
data_set['MinTemp'].median()
data_set['MinTemp'].mode()
# Out:
# 0    0.5
# 1    4.4
# dtype: float64
